# %% [markdown]
# # 损失函数
#
# 在深度学习中, **损失函数是用来衡量模型参数的质量的函数**, 衡量的方式是比较网络输出和真实输出的差异。下面按照不同的任务类型,来介绍常见的损失函数
#
# > 作用:指导模型的训练过程，通过反向传播算法计算梯度，从而更新网络的参数，最终使得模型的预测结果尽可能接近真实值。损失函数的选择对模型训练的收敛速度、效果和稳定性具有重要影响。

# %%
import torch

# %%
torch.nn.CrossEntropyLoss(beta=1.0)
